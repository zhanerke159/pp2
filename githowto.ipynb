# %% [markdown]
# Setting up name and email address

# %% [markdown]
# ![Снимок экрана 2025-01-16 130159.png](<attachment:Снимок экрана 2025-01-16 130159.png>)

# %% [markdown]
# Default branch name

# %% [markdown]
# ![Снимок экрана 2025-01-16 130535.png](<attachment:Снимок экрана 2025-01-16 130535.png>)

# %% [markdown]
# Line endings treatment

# %% [markdown]
# ![Снимок экрана 2025-01-16 130651.png](<attachment:Снимок экрана 2025-01-16 130651.png>)

# %% [markdown]
# Creting page

# %% [markdown]
# ![Снимок экрана 2025-01-16 131813.png](<attachment:Снимок экрана 2025-01-16 131813.png>)

# %% [markdown]
# creating a repository

# %% [markdown]
# ![Снимок экрана 2025-01-16 133745.png](<attachment:Снимок экрана 2025-01-16 133745.png>)

# %% [markdown]
# adding a repository to

# %% [markdown]
# ![Снимок экрана 2025-01-16 133751.png](<attachment:Снимок экрана 2025-01-16 133751.png>)

# %% [markdown]
# checking the status

# %% [markdown]
# ![Снимок экрана 2025-01-16 133822.png](<attachment:Снимок экрана 2025-01-16 133822.png>)

# %% [markdown]
# changes to the code

# %% [markdown]
# ![Снимок экрана 2025-01-16 133925.png](<attachment:Снимок экрана 2025-01-16 133925.png>)

# %% [markdown]
# checking the status

# %% [markdown]
# ![Снимок экрана 2025-01-16 134257.png](<attachment:Снимок экрана 2025-01-16 134257.png>)

# %% [markdown]
# checking the status and indexing changes

# %% [markdown]
# ![Снимок экрана 2025-01-16 134439.png](<attachment:Снимок экрана 2025-01-16 134439.png>)

# %% [markdown]
# Commit and editor

# %% [markdown]
# ![Снимок экрана 2025-01-16 143312.png](<attachment:Снимок экрана 2025-01-16 143312.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 143548.png](<attachment:Снимок экрана 2025-01-16 143548.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 143659.png](<attachment:Снимок экрана 2025-01-16 143659.png>)

# %% [markdown]
# Checking the status

# %% [markdown]
# ![Снимок экрана 2025-01-16 143811.png](<attachment:Снимок экрана 2025-01-16 143811.png>)

# %% [markdown]
# Adding standard tags

# %% [markdown]
# ![Снимок экрана 2025-01-16 190939.png](<attachment:Снимок экрана 2025-01-16 190939.png>)

# %% [markdown]
# Adding this changes

# %% [markdown]
# ![Снимок экрана 2025-01-16 143950.png](<attachment:Снимок экрана 2025-01-16 143950.png>)

# %% [markdown]
# The second change

# %% [markdown]
# ![Снимок экрана 2025-01-16 191120.png](<attachment:Снимок экрана 2025-01-16 191120.png>)

# %% [markdown]
# Commit

# %% [markdown]
# ![Снимок экрана 2025-01-16 144059.png](<attachment:Снимок экрана 2025-01-16 144059.png>)

# %% [markdown]
# Adding the second change

# %% [markdown]
# ![Снимок экрана 2025-01-16 144132.png](<attachment:Снимок экрана 2025-01-16 144132.png>)

# %% [markdown]
# Commit for second change

# %% [markdown]
# ![Снимок экрана 2025-01-16 144210.png](<attachment:Снимок экрана 2025-01-16 144210.png>)

# %% [markdown]
# History

# %% [markdown]
# ![Снимок экрана 2025-01-16 144347.png](<attachment:Снимок экрана 2025-01-16 144347.png>)

# %% [markdown]
# One-line story

# %% [markdown]
# ![Снимок экрана 2025-01-16 144353.png](<attachment:Снимок экрана 2025-01-16 144353.png>)

# %% [markdown]
# The final format of the log

# %% [markdown]
# ![Снимок экрана 2025-01-16 144543.png](<attachment:Снимок экрана 2025-01-16 144543.png>)

# %% [markdown]
# after receiving the hashes of previous commits, substituting the hash from the repository

# %% [markdown]
# ![Снимок экрана 2025-01-16 145229.png](<attachment:Снимок экрана 2025-01-16 145229.png>)

# %% [markdown]
# Revert to the latest version in the main branch

# %% [markdown]
# ![Снимок экрана 2025-01-16 145318.png](<attachment:Снимок экрана 2025-01-16 145318.png>)

# %% [markdown]
# The tag of the first version

# %% [markdown]
# ![Снимок экрана 2025-01-16 145351.png](<attachment:Снимок экрана 2025-01-16 145351.png>)

# %% [markdown]
# Tags for previous versions

# %% [markdown]
# ![Снимок экрана 2025-01-16 145604.png](<attachment:Снимок экрана 2025-01-16 145604.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 145651.png](<attachment:Снимок экрана 2025-01-16 145651.png>)

# %% [markdown]
# Switching by tag name

# %% [markdown]
# ![Снимок экрана 2025-01-16 145722.png](<attachment:Снимок экрана 2025-01-16 145722.png>)

# %% [markdown]
# use the tag command to view the available tags

# %% [markdown]
# ![Снимок экрана 2025-01-16 145746.png](<attachment:Снимок экрана 2025-01-16 145746.png>)

# %% [markdown]
# tags that are in the log

# %% [markdown]
# ![Снимок экрана 2025-01-16 145814.png](<attachment:Снимок экрана 2025-01-16 145814.png>)

# %% [markdown]
# checking the status after switching to the main branch and making changes hello.html the file

# %% [markdown]
# ![Снимок экрана 2025-01-16 150126.png](<attachment:Снимок экрана 2025-01-16 150126.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 150016.png](<attachment:Снимок экрана 2025-01-16 150016.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 150145.png](<attachment:Снимок экрана 2025-01-16 150145.png>)

# %% [markdown]
# Undoing changes in the working directory

# %% [markdown]
# ![Снимок экрана 2025-01-16 150254.png](<attachment:Снимок экрана 2025-01-16 150254.png>)

# %% [markdown]
# Changing html file again and indexing, also checking status

# %% [markdown]
# ![Снимок экрана 2025-01-16 195930.png](<attachment:Снимок экрана 2025-01-16 195930.png>)

# %% [markdown]
# ![Снимок экрана 2025-01-16 150354.png](<attachment:Снимок экрана 2025-01-16 150354.png>)

# %% [markdown]
# resetting the HEAD preparation area

# %% [markdown]
# ![Снимок экрана 2025-01-16 150430.png](<attachment:Снимок экрана 2025-01-16 150430.png>)

# %% [markdown]
# checking if the directory is clean

# %% [markdown]
# ![Снимок экрана 2025-01-16 150503.png](<attachment:Снимок экрана 2025-01-16 150503.png>)
